# %% [markdown]
# # In-class Assignment 6.1
#
# **Week 6 Monday**

# %% [markdown]
# #### &#x2705; Gwen, Caleb, Carter, and Hannah

# %% [markdown]
# In ICA 5.2, you...
# - loaded the `.wav` files for guitar and banjo musical notes into your notebook.
# - played them out loud to hear the differences between guitar and banjo sounds.
# - plotted the amplitudes to visualize differences in the audio files.
# - began to pose questions that you might want to investigate.

# %% [markdown]
# Today, we continuing the modeling cycle.
#
# - **(1)** Pose a question of a real-world physics phenomena.
# - **(2a)** Make assumptions about the phenomenon to simplify it into a form that balances two priorities: addressing the core of the question and creating a computational model of the phenomenon.
# - **(2b)** Review the resources you have that might be useful for creating a model to answer the question, including: computing/programming tools, physics concepts, numerical methods, existing models.
# - **(3a)** Make a plan for creating or refining a computational model, and design tests to validate its effectiveness at answering the question.
# - **(3b)** Create or refine a new computational model using your resources and the shared expertise of your group, stepping back to critique and update your plan as needed.
# - **(4)** Test the effectiveness of your model using your planned validation process.

# %% [markdown]
# ---
#
# ## Part 1: Deciding assumptions and resources
#
# You might have created a very detailed question with your group already, or you might have just started considering the topic you want to investigate. Either way, it's worthwhile to spend some time how your assumptions and resources will align with your investigation.

# %% [markdown]
# &#x2705; Consider the Fourier Transform from the PCA as a possible resource for your group. As a group, discuss and decide:
# - What assumptions about the physics phenomenon (sound waves produced from banjo and guitar) do you need to make to use a Fourier Transform?
# - Can you make those assumptions and still answer your question?
#
#
# - We are assuming that they are they same instrument even though the audios sense recorded from the web are from different audio files. They will in reality be different recordings. The resource used are most likely from the same guitar.
# - audio files for C3,C4,C5
# - the instruments are in tune
# - no extra decay that is happening

# %% [markdown]
# ---
#
# ## Part 2: Planning and implementing your computational model
#
# Based on the assumptions you made and the available resources that can be used, you can plan your implementation of your computational model.
#
# &#x2705; As a group, make a plan that includes the specific aspects of your computational model and a actions you can take to see whether your model answers your question. Once your group all agrees on a plan, you get started with implementing your model.

# %% [markdown]
# - We are going to use recordings of a guitar for C3, C4, C5 and get different plots of each.
# - Generate a plot of each octave to look at the initial behavior
# - Do fourier transformation for each of the recordings and then generate a one plot of the three octaves
# - Compare the steps between each octave to see if recordings are in tune
