# %% [markdown]
# # In-class Assignment 5.2
#
# **Week 5 Wednesday**

# %% [markdown]
# #### &#x2705; Carter Hunt

# %% [markdown]
# Today we start a new modeling cycle on the same topic we modeled recently: vibrations of strings. This time, we compare more complex vibrations: a guitar and a banjo.

# %% [markdown]
# ---
#
# ## Part 1: Get a feel for the audio files
#
# To begin, take a look at the data you'll use during this modeling cycle. You'll find two files located in the `hub_data_share/data/` directory, `guitar-mono.wav` and `banjo-mono-wav`. These are audio recordings of each instrument plucked at a musical C note.

# %% [markdown]
# &#x2705; Read the files into the jupyter notebook using [**scipy.io.wavfile.read**](https://docs.scipy.org/doc/scipy/reference/generated/scipy.io.wavfile.read.html).

# %%
from scipy.io import wavfile
import numpy as np

sample_rate, data = wavfile.read('/home/huntcar/hub_data_share/data/banjo-mono.wav')
sample_rate, data = wavfile.read('/home/huntcar/hub_data_share/data/guitar-mono.wav')


duration = data.shape[0] / sample_rate
time = np.linspace(0., duration, data.shape[0])

print("Sample rate:", sample_rate)
print("Array shape:", data.shape)
print("Array dtype:", data.dtype)
print("data:", data)
print("duration:", duration)
# Out:
# Sample rate: 44100
# Array shape: (132300,)
# Array dtype: int16
# data: [0 0 0 ... 1 0 1]
# duration: 3.0

# %% [markdown]
# &#x2705; Use [**IPython.display.Audio**](https://ipython.readthedocs.io/en/stable/api/generated/IPython.display.html) to play the audio out loud from your jupyter notebook.

# %%
from IPython.display import Audio as ad

ad(data, '/home/huntcar/hub_data_share/data/banjo-mono.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ad(guitar, '/home/huntcar/hub_data_share/data/guitar-mono.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import matplotlib.pyplot as plt
t = np.linspace(0,3,132300)
plt.plot(t, data, color = "rebeccapurple");

# %%
x = np.linspace(0,3,176400)
plt.plot(x, guitar, color = "palevioletred");

# %% [markdown]
# &#x2705; Create a visualization of each audio recording. Discuss how they compare qualitatively.

# %% [markdown]
# ---
#
# ## Part 2: Posing a question
#
# Now that you have some familiarity with each recording, what is a question you and your group could investigate further?
#
# Keep in mind that you will be attempting each step of the modeling cycle from here:
#
# - **(1)** **(You are here)** Pose a question of a real-world physics phenomena.
# - **(2a)** Make assumptions about the phenomenon to simplify it into a form that balances two priorities: addressing the core of the question and creating a computational model of the phenomenon.
# - **(2b)** Review the resources you have that might be useful for creating a model to answer the question, including: computing/programming tools, physics concepts, numerical methods, existing models.
# - **(3a)** Make a plan for creating or refining a computational model, and design tests to validate its effectiveness at answering the question.
# - **(3b)** Create or refine a new computational model using your resources and the shared expertise of your group, stepping back to critique and update your plan as needed.
# - **(4)** Test the effectiveness of your model using your planned validation process.
#
# To evaluate whether a question is answerable, **consider the resources you have access to.** The recordings themselves are valuable data about the physics phenomenon of sound waves produced by each musical instrument. You also recently learned about Fourier series and finite-difference methods. Is there a way to use any of these resources together? What insight could you gain from that?

# %% [markdown]
# &#x2705; Craft a question that you and your group want to answer related to comparing the audio recordings, and list the main assumptions and resources you intend to use to answer it.
#
# * How do waveform graphs differ for the same note played in different octaves on the same instrument?
# * Assumptions:
#     * Using the same instrument and same string material
#     * Pulling .wav files from the internet so they may actually be different
